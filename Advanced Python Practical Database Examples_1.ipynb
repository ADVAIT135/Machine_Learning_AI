# %% [markdown]
# # LinkedIn Learning
# # Advanced Python: Practical Database Examples

# %% [markdown]
# ## 1. Creating an API that serves Data from a Database with FastAPI

# %% [markdown]
# ### A. Set up FastAPI in a Python application

# %% [markdown]
# ![image.png](attachment:ad5338c8-9dc7-4c93-aef8-fbdad22c1bb4.png)

# %% [markdown]
# ![image.png](attachment:de483d7f-b43d-4c5c-8a40-3404bc919e14.png)

# %% [markdown]
# ![image.png](attachment:fe60edc3-3c71-44cb-a7b0-509ee227c3b0.png)

# %% [markdown]
# ![image.png](attachment:e6b88e4a-01a9-4bfb-9599-ae1640e36d12.png)

# %% [markdown]
# ![image.png](attachment:65fdc817-7b00-4f81-90a0-eb95377c94cc.png)

# %% [markdown]
# ![image.png](attachment:0816d452-8923-4456-8fe7-8ab63a5bc4bd.png)

# %% [markdown]
# ![image.png](attachment:b3cf0345-bf24-4265-8bd5-3d771aab1ad6.png)

# %% [markdown]
# ![image.png](attachment:21c23b7e-6791-4b3a-9745-d25d3753a325.png)

# %% [markdown]
# ![image.png](attachment:4496ffe1-60fd-495d-87e0-a2bb5e620bcd.png)

# %% [markdown]
# ![image.png](attachment:0fc1a1b3-5350-4929-9902-02876c191995.png)

# %% [markdown]
# ![image.png](attachment:fa1f89ea-11cf-4c19-8690-929ab47f5b96.png)

# %% [markdown]
# ### B. Define a database Schema

# %% [markdown]
# ![image.png](attachment:f121f95c-158c-4c45-9c9b-de47c05ca567.png)

# %% [markdown]
# ![image.png](attachment:6feb76e5-017c-49ed-ae4a-e33234fa974c.png)

# %% [markdown]
# ![image.png](attachment:47c3fb4d-326e-464f-9e89-e05735c3cd28.png)

# %% [markdown]
# ![image.png](attachment:cc64e4b9-1ea3-4f6c-9473-086aad7a34db.png)

# %% [markdown]
# ### C. Create MySQL Database

# %% [markdown]
# ![image.png](attachment:487073fe-65f2-457e-927c-c1f0fbcad125.png)

# %% [markdown]
# ![image.png](attachment:365883dc-1a72-4e79-bf31-8f6d2fa5fdd0.png)

# %% [markdown]
# ![image.png](attachment:4981f75a-a39d-46b7-8dd5-83f80b1e9826.png)

# %% [markdown]
# ### D. Create an API Contract

# %% [markdown]
# ![image.png](attachment:22a7378e-59bf-46f8-9dae-91563ee5f8ba.png)

# %% [markdown]
# ### E. Build a POST endpoint with FastAPI

# %% [markdown]
# ![image.png](attachment:9a244aed-ff7c-48ad-aeff-f5b8be7e9f5a.png)

# %% [markdown]
# ![image.png](attachment:f6343ace-c958-4653-a892-046d433f0c15.png)

# %% [markdown]
# ### F. Call a new API using Postman

# %% [markdown]
# ![image.png](attachment:130b31f5-e757-4491-acb3-913edb8814f5.png)

# %% [markdown]
# ![image.png](attachment:85807b6d-ffe5-48f9-b5a2-6c75aeaec7ae.png)

# %% [markdown]
# ![image.png](attachment:19e1e28f-5044-48d0-a790-7c2ded30d30a.png)

# %% [markdown]
# ![image.png](attachment:7857a8a6-7f5e-40e7-bb70-8a067f24a015.png)

# %% [markdown]
# ![image.png](attachment:0d4a907c-026b-4eed-9421-b686a815c4bc.png)

# %% [markdown]
# ### G. Add data to a database in Python using SQLAlchemy

# %% [markdown]
# ![image.png](attachment:70b2f724-9694-4a91-bcc2-6c72988acbef.png)

# %% [markdown]
# ### H. Integrate a database with a FastAPI application

# %% [markdown]
# ![image.png](attachment:7bcdcb61-4f7d-4010-9881-accba847763f.png)

# %% [markdown]
# ![image.png](attachment:d741de28-4480-4503-9e2d-f43f54056eb4.png)
